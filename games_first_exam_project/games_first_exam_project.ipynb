# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Итак, мои комментарии на этот раз будут зелёными, в заголовке иметь версию V2 (как у этого!) и в них я буду стараться ответить на твои вопросы, если таковые увижу (мелкие/"проходные" изменения/исправления в тексте проекта, каждое из них, не буду с твоего позволения комментировать - только те моменты, где я что-то более-менее не банальное могу сказать. Хорошо? Будем считать, что, если комментария на твое исправление нет - значит я согласен с тобой в этом пункте).
#
# ………………
#
# Павел, вижу, что все красные комментарии учтены, код исправлен, выводы актуализированы. Соответственно никаких вопросов/моментов/комментариев, мешающих принять твой проект у меня более нет.
#
# ПРОЕКТ ПРИНЯТ!
#
# Я же в свою очередь, ниже попытался ответить на все твои вопросы (если видел, что они есть).
#
# Павел - СУПЕР ПРОГРЕСС у тебя! Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# p.s. Павел, на адрес твоей почты сейчас пришлю полезные материалы по анализу данных (из своей электронной библиотеки). Возможно они будут полезны тебе и станут подспорьем в учебе.</div>

# %% [markdown]
# Привет Павел!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике. Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что в следующий раз можно сделать по-другому. "Жёлтые" комментарии не требуют твоих правок в проекте и их наличие НИКАК не повлияет на результат моей проверки. Но я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет.
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# Ну и наконец информируй меня в том случае, если по твоему проекту подходит дедлайн! В таком случае я приложу усилия, чтобы ты сдал(а) его вовремя; буду оперативно, в приоритете проверять итерации ревью, а также отвечать на твои вопросы, если этого будет требовать ситуация.
#
# **Распространенные недочёты в проектах:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
#
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
#
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
#
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
#
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>В первую очередь хочу поблагодарить за подробное ревью и полезную информацию!
#         Чтобы было понятнее, с чьей работой ты имеешь дело, я всю жизнь проработал поваром и начал знакомство с python и программированием в целом 4-5 месяцев назад. до этого момента мои познания в IT были равны 0. С Pandas и прочими библиотеками познакомился только на этом курсе. С играми я в последний раз сталкивался больше 20 лет назад, когда играл в них на денди и сеге и абсолютно ничего не знаю о платформах и о сфере в целом.
#     То, что я буду исправлять, буду писать в ячейках под твоими комментами, а свои изначальные решения закомментирую и оставлю там, где они и были</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Павел, ну тогда могу сказать, что ты круто и быстро идешь к цели! Не шучу! В твоем проекте всего 3 красных ошибки. Это ниже среднего числа ошибок. В среднем их 5-8 в "типовой работе".
#
# Но бывает и больше. Значительно больше. Вот например ниже скрин этого же, Сборного 1-5, который я сегодня проверял ...
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# # Исследование популярности игр и игровых платформ

# %% [markdown]
# цель исследования: выявить определяющие успешность игры закономерности на основании данных о рейтингах критиков и пользователей, и о количестве продаж в разных регионах до 2016 года для планирования рекламной кампании 2017

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st

# %%
try:
    df = pd.read_csv("D:\\практикум\\датасеты для проектов\\games.csv")
except:
    df = pd.read_csv("/datasets/games.csv")

display(df.head())
df.info()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здесь хорошо! При такой загрузке данных и тебе комфортно работать с проектом на домашнем ПК и у меня всё ОК во время проверки проекта в Юпитер Хабе</div>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-warning">
# <b>Предложение 👉</b>
#
# **df.duplicated().sum() == 0** не означает, что в данных нет дубликатов (записей).
#
# Попробуй найти неявные дубликаты (для их поиска нужно  использовать параметр **subset**). Ну а в нашем рабочем проекте пробуй найти дубликаты для пары "Имя - Игровая консоль".
#
# Как их планируешь и планируешь ли обрабатывать?</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>я отнес простое действие проверки наличия явных дубликатов к разделу первоначального и общего просмотра данных, и в выводе этого раздела отметил лишь отсутствие ЯВНЫХ дубликатов. В дальнейшем в разделе предобработки я нашел неявные.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Ок, понял.
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# итак: у нас есть таблица из 11 столбцов. в 6 присутствуют пропуски. Названия колонок не приведены к нижнему регистру. по типам данных всё в порядке, не считая столбца с оценкой пользователей. Явных дубликатов нет.

# %% [markdown]
# ## Предобработка

# %%
# приводим названия столбцов к нижнему регистру
# df.columns = [x.lower() for x in df.columns]
# df.head()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Так можно, но проще (с точки зрения количества кода) сделать это через str.lower().</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>в одной из предыдущих работ делал это через str.lower() а приемом df.columns = [x.lower() for x in df.columns] еще не пользовался. просто руки чесались попробовать. это нам показывали на одном из вебинаров. в основной программе обучения этот прием не проходили</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Ок, понял. Не проблема Павел. Просто я на код смотрю с точки зрения простоты его и целесообразности использования в повседневной работе аналитика. Возможно я иногда забываю, что вы на учебных проектах обкатываете различные варианты, учитесь другими словами. Молодец что тестируешь разные варианты.
# </div>

# %%
df.columns = df.columns.str.lower()
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
# отсутствующие названия игр
df[df["name"].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# 2 игры бородатого года практически без полезной информации. и как раз те 2 игры в которых пропущен жанр. от них можно избавиться

# %%
# df = df.dropna(subset=["name"]).reset_index(drop=True)
# df["name"].isna().sum()

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Молодец! Правильный вывод! И порядок действий правильный - вначале посмотреть на данные, а уже потом принимать решение.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# И ещё небольшой, но жизненный совет: **перед** и **сразу после** удаления строк (и для столбцов тоже будет верно) примени метод .shape к датафрейму. В этом случае наглядно будет видно сколько строк/столбцов было удалено. В некоторых ситуациях может быть ошибка в коде из-за которой удаляется больше чем ожидалось. Но этот способ поможет тебе такую проблему сразу вычислить.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>ок
#     </font>
# </div>

# %%
display(df.shape)
df = df.dropna(subset=["name"]).reset_index(drop=True)
df.shape
# Out:
# (16715, 11)
# (16713, 11)

# %%
display(df[["name", "platform"]].duplicated().sum())
df[df[["name", "platform"]].duplicated()]
# Out:
# 4
#                               name platform  year_of_release     genre  \
# 1590   Need for Speed: Most Wanted     X360           2005.0    Racing
# 4126            Sonic the Hedgehog      PS3              NaN  Platform
# 11714  Need for Speed: Most Wanted       PC           2012.0    Racing
# 16228                Madden NFL 13      PS3           2012.0    Sports
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 1590        1.0      0.13      0.02         0.10          83.0        8.5
# 4126        0.0      0.48      0.00         0.00          43.0        4.1
# 11714       0.0      0.06      0.00         0.02          82.0        8.5
# 16228       0.0      0.01      0.00         0.00          83.0        5.5
#
#       rating
# 1590       T
# 4126    E10+
# 11714      T
# 16228      E

# %% [markdown]
# 4 неявных дубликата.

# %%
df.query('name == "Need for Speed: Most Wanted" and (platform == "X360" or platform == "PC") \
or name == "Sonic the Hedgehog" and platform == "PS3" or name == "Madden NFL 13" and platform =="PS3"')
# Out:
#                               name platform  year_of_release     genre  \
# 604                  Madden NFL 13      PS3           2012.0    Sports
# 1189   Need for Speed: Most Wanted     X360           2012.0    Racing
# 1590   Need for Speed: Most Wanted     X360           2005.0    Racing
# 1744            Sonic the Hedgehog      PS3           2006.0  Platform
# 4126            Sonic the Hedgehog      PS3              NaN  Platform
# 5971   Need for Speed: Most Wanted       PC           2005.0    Racing
# 11714  Need for Speed: Most Wanted       PC           2012.0    Racing
# 16228                Madden NFL 13      PS3           2012.0    Sports
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 604        2.11      0.22      0.00         0.23          83.0        5.5
# 1189       0.62      0.78      0.01         0.15          83.0        8.5
# 1590       1.00      0.13      0.02         0.10          83.0        8.5
# ...

# %% [markdown]
# nfs выходили в разные годы - это не дубликаты, хотя при этом рейтинги критиков и пользователей идентичны. Все данные по продажам отличаются и у одной игры отсутствует год. пожалуй, здесь все сотит оставить, как есть.

# %%
df["platform"].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: platform, dtype: int64

# %% [markdown]
# присутствуют платформы на которых было выпущено по одной игре, но гугл говорит, что такие платформы существуют, а значит это не опечатки

# %%
df["year_of_release"].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %% [markdown]
# есть пропуски, но достоверных данных для их заполнения нет и смысла тоже

# %%
df["year_of_release"].isna().mean()
# Out:
# 0.016095255190570215

# %% [markdown]
# пропусков всего полтора процента. оставим, как есть

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Я бы после анализа удалил эти записи. Их всего 269 (из 16+ тысяч), меньше 2%. "Погоды" они нам не сделают.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>подумал, что на этом этапе еще где-то могут понадобиться данные имеющиеся в остальных столбцах. а пропуски отсекутся, когда будет выбран актуальный период
#     </font>
# </div>

# %%
df["genre"].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %% [markdown]
# Здесь порядок.

# %%
df[["na_sales", "eu_sales", "jp_sales", "other_sales"]].describe()
# Out:
#            na_sales      eu_sales      jp_sales   other_sales
# count  16713.000000  16713.000000  16713.000000  16713.000000
# mean       0.263302      0.145045      0.077625      0.047343
# std        0.813565      0.503359      0.308871      0.186742
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.080000      0.020000      0.000000      0.010000
# 75%        0.240000      0.110000      0.040000      0.030000
# max       41.360000     28.960000     10.220000     10.570000

# %% [markdown]
# Первый квартиль у всех на нуле и медияна тоже бизка к нулю. Большая разница между медианой и средним. Максимальные значения колоссально рознятся со редним. стоит посмотреть на разброс наглядно

# %%
df[["na_sales", "eu_sales", "jp_sales", "other_sales"]].hist(bins=40, range=(0, 3), figsize=(14, 10))
plt.show()

# %% [markdown]
# судя по всему большинство игр не выпускалось в определенных регионах, либо по продажам отсутствуют данные и явно видно, что основные продажи приходятся на малую долю самых популярных игр.

# %%
display(df["critic_score"].unique())
df["critic_score"].isna().mean()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 22., 13.])
# 0.5131334889008556

# %% [markdown]
# Больше половины пропусков, вероятнее всего, оценок критиков просто не было. не вижу смысла заполнять.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Всё так, не будем сбивать статистики в наших данных.
# </div>

# %%
# можно было бы заполнить заглушкой
# df["critic_score"] = df["critic_score"].fillna(-1)
# df["critic_score"].isna().sum()

# %%
display(df["user_score"].unique())
display(df["user_score"].isna().mean())
len(df[df["user_score"] == "tbd"]) / len(df)
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)
# 0.400825704541375
# 0.14503679770238737

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# В библиотеке Pandas более типичным способом получения информации о размерности датафрейма  является использование метода **shape**, а не функции **len()** или **info()**. Так (**псевдокод**): df.shape[0] – «покажет» количество строк в датафрейме, а shape[1] - количество столбцов.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>не знал про shape[0] и shape[1]. Спасибо за инфу! но, если честно, так и не разобрался, как применить это в данном конкретном случае. в дальнейшем буду пользоваться
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Смотри, по шагам:
#
# 1. Для некоего датафрейма (df) выполнил df.shape. Получил output: (16375, 11). Это значит что в данных 16375 строк и 11 столбцов.
#
# 2. Предположим удалил дубликаты (удалил несколько записей / удалил несколко столбцов).
#
# 3. Опять запустил df.shape. Получил output: (12567, 8). Это значит что в данных **стало** 12567 строк и 18 столбцов. Налицо видно чего и сколько удалилось.
# </div>

# %% [markdown]
# больше 14 процентов tbd(to be determined), а значит по сути это те же пропуски/

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# То, что ты tbd меняешь на NaN - это правильно. По сути это и есть пропуски (строки с играми, для которых оценка не проставлена, пропущена по каким-то причинам).</div>

# %%
df["user_score"] = df["user_score"].replace("tbd", np.nan).astype("float")
# и снова можно заполнить лишь заглушкой, но не ясно зачем
# df["user_score"] = df["user_score"].fillna(-1).astype("float")
df["user_score"].unique()
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7])

# %%
df["rating"].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Рейтинг K-A - это устаревший E, а RP по сути отсутствие рейтинга

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Скажи пожалуйста, какова на твой взгляд причина того, что в столбце с оценками экспертов, с оценками пользователей и с рейтингами так много пропусков? Как ты считаешь, может ли быть какая-то связь с тем, что в столбце с рейтингами >40% пропусков и тем, что эти оценки (рейтинги) выставляет **именно Американское рейтинговое агентство?</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Ну с такими недвусмысленными намёками я прямо сразу начал догадываться в чем тут дело)).
#     </font>
# </div>

# %% [markdown]
# Я так понимаю, Американское рейтинговое агентство присваивает рейтинги только тому, что выпускается в Америке, с чем и связано большое количество пропусков в колонке с возрастными рейтингами

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# )))))
#
# Рейтинг ESRB - это американский рейтинг, а в Японии есть своё рейтинговое агентство. Получается, что Япония страна со своим менталитетом. И твой анализ должен показать, что Японцы в игры-то играют не такие, как весь прочий мир и жанры игр там популярны совсем другие, нежели в остальном мире, да и на рейтинги (не своего агентства) не очень то внимание обращают.</div>
# </div>

# %%
# заменяем K-A на E, добавляем категорию unknown, заполняем пропуски
df["rating"] = df["rating"].fillna("unknown").replace(["K-A", "RP"], ["E", "unknown"])
df["rating"].unique()
# Out:
# array(['E', 'unknown', 'M', 'T', 'E10+', 'AO', 'EC'], dtype=object)

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, принято правильное решение! «Заглушка» для NaN значений в столбце ‘rating’ – это верное решение в этом проекте. Далее, когда ты будешь анализировать особенности регионов в зависимости от рейтинга ESRB, то увидишь, что если бы они остались NaN, то на графиках их не было бы видно, также такие игры "выпали" бы из анализа и выводов, а это красная ошибка в этом проекте.</div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16713 entries, 0 to 16712
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16713 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# То, что ты в 'critic_score' и 'user_score' (после обращения tbd в NaN) оставляешь NaN'ы без обработки - значительно упростит тебе жизнь дальше. В этом проекте - это верное решение.</div>

# %%
# добавляем столбец с суммарными продажами
# df["total_sales"] = df["na_sales"] + df["eu_sales"] + df["jp_sales"] + df["other_sales"]
# df.head()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Ещё такой вариант суммирования есть (просто как альтернатива … **псевдокод**): **data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis='columns')** и "присвоить" этот результат новому столбцу в **data**.</div>

# %%
df["total_sales"] = df[["na_sales", "eu_sales", "jp_sales", "other_sales"]].sum(axis="columns")
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score   rating  \
# 0     28.96      3.77         8.45          76.0         8.0        E
# 1      3.58      6.81         0.77           NaN         NaN  unknown
# 2     12.76      3.79         3.29          82.0         8.3        E
# 3     10.93      3.28         2.95          80.0         8.0        E
# 4      8.89     10.22         1.00           NaN         NaN  unknown
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# ...

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>так посимпатичнее. с таким приемом тоже не сталкивался
#     </font>
# </div>

# %%
# проверяем количество нулей в общих продажах и в продажах по регионам
# display(len(df[(df["na_sales"] == 0) | (df["eu_sales"] == 0) | (df["jp_sales"] == 0) | (df["other_sales"] == 0)]))
display(len(df.query('na_sales == 0 or eu_sales == 0 or jp_sales == 0 or other_sales == 0')))
len(df[df["total_sales"] == 0])
# Out:
# 14320
# 2

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# В библиотеке Pandas более типичным способом получения информации о размерности датафрейма  является использование метода **shape**, а не функции **len()** или **info()**. Так (**псевдокод**): df.shape[0] – «покажет» количество строк в датафрейме, а shape[1] - количество столбцов.</div>

# %%
display(df.query('na_sales == 0 or eu_sales == 0 or jp_sales == 0 or other_sales == 0').shape)
df[df["total_sales"] == 0].shape
# Out:
# (14320, 12)
# (2, 12)

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>учел
#     </font>
# </div>

# %% [markdown]
# гипотеза об отсутствии продаж определенных игр в определенных регионах подтвердилась

# %% [markdown]
# ### Вывод

# %% [markdown]
# В ходе предобработки данных названия колонок приведены к стандартному виду. Частично заполнены пропуски. в данных по продажам обнаружена большая доля нулевых значений сильные выбросы связанные с большой популярностью определенных игр. Добавлен столбец с суммарными продажами. обнаружены дубликаты игр с разными значениями в графах продаж по регионам

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Данные загружены, отлично.
#
# Хорошо, что применяешь метод .head()/.sample() таким образом в память не будет загружен весь датасет, объем которого может быть огромным.
#
# Методы .info, .describe, .value_counts(), .unique() как правило часто встречаются и обязательны к применению в задачах по исследованию данных, ведь с их помощью можно получить первые инсайты.
#
# Итак, мы провели предварительный анализ данных, проверили данные на наличие пропусков и затем обработали их (аргументированно заполнили / удалили / оставили как есть). Теперь можно приступать и к EDA (== Exploratory Data Analysis).</div>

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# Посмотрим на распределение количества игр и суммарных продаж по годам

# %%
plt.figure(figsize=(20, 10))
df["year_of_release"].hist(bins=37, label="выпущено игр, шт/год")
x = df.groupby("year_of_release")["total_sales"].sum().plot(style="-o", label="общие продажи, Млн копий/год")
plt.title("Pаспределение количества игр и суммарных продаж по годам ")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# мы видим, что начиная с 95го года количество выпусаемых игр стало постоянно и значительно увеличиваться, соответственно увеличились и продажи, однако, относительно количества выпускаемых игр, продажи были выше, но не стоит забывать, что не смотря на устаревание игр, их продажи так или иначе растут с течением времени, возможно по этому при небольшом разнообразии игр мы видим высокие значения продаж. По этой же причине, вероятно, продажи 15-16 года находятся на таком низком уровне. Полагаю, это не окончательные значения продаж 16 года.
# Количество выпускаемых игр достигло пика, как и продажи в 8-9 году и достаточно резко обвалилось в 12. Идальше постепенно пошло на спад. Посмотрим поближе на ситуацию начиная с 1995

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Этот график, как и все прочие ниже, выиграли бы если бы были подписаны сами, а также оси X и Y, а также указаны единицы измерения по осям.
#
# p.s. здорово, что есть объяснение поведения данного графика. Пытаться понять полученный результат - важная часть работы аналитика.</div>

# %%
df = df[df["year_of_release"] >= 1995]
# платформы с наибольшими суммарными продажами
platform_total_sales = (
    df.pivot_table(index="platform", values="total_sales", aggfunc="sum")
    .sort_values(by="total_sales", ascending=False)
)
# platform = platform[platform["total_sales"] > 0]
platform_total_sales.head(20)
# Out:
#           total_sales
# platform
# PS2           1233.56
# X360           961.24
# PS3            931.34
# Wii            891.18
# DS             802.76
# PS             721.55
# PS4            314.14
# GBA            312.88
# PSP            289.53
# 3DS            257.81
# XB             251.57
# PC             239.79
# N64            218.01
# GC             196.73
# XOne           159.32
# GB             139.90
# WiiU            82.19
# PSV             53.81
# SNES            49.59
# SAT             29.94

# %%
# таблица с суммарными продажами платформ по годам
platform_sales = df.pivot_table(index="platform",columns="year_of_release", values="total_sales", aggfunc="sum")
# объединяем с таблицей-рейтингом продаж
platform_pivot = platform_total_sales.join(platform_sales).drop("total_sales", axis=1)
# platform = platform.fillna(0)
# с незаполненными пропусками хитмэп выглядит круче
plt.figure(figsize=(20, 10))
sns.heatmap(platform_pivot, annot=True, fmt=".3g", cmap="Blues", linewidths=1, linecolor="gray")
# Out:
# <AxesSubplot:ylabel='platform'>

# %% [markdown]
# Отлично прослеживаются жизненные циклы платформ. Видно, что в основном платформы живут 10-12 лет, что никак не затрагивает PC. Также мы видим, что рейтинг возглавляют трупы шестерки лидеров. рассмотрим их нагляднее

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Подтверждаю 7-9-11 лет, как корректный интервал, описывающий средний срок жизни игровой платформы.</div>

# %%
# распределения суммарных продаж топовых платформ по годам
ps2 = df[df["platform"] == "PS2"].groupby("year_of_release")["total_sales"].sum()
x360 = df[df["platform"] == "X360"].groupby("year_of_release")["total_sales"].sum()
ps3 = df[df["platform"] == "PS3"].groupby("year_of_release")["total_sales"].sum()
wii = df[df["platform"] == "Wii"].groupby("year_of_release")["total_sales"].sum()
plt.bar(ps2.index, ps2)
plt.title("PS2")
plt.grid()
plt.figure()
plt.title("X360")
plt.grid()
plt.bar(x360.index, x360)
plt.figure()
plt.title("PS3")
plt.grid()
plt.bar(ps3.index, ps3)
plt.figure()
plt.title("Wii")
plt.grid()
plt.bar(wii.index, wii)
plt.show()

# %% [markdown]
# у PS2 видна некоторая скошенность вправо. Два следующих стремятся к нормальному, а у Wii, что-то больше похожее на распределение Пуассона стремящееся к нормальному. Главное, что мы видим - это то, что предположение о 10-12летнем жизненном цикле платформ подтверждается. Полагаю, стоит поближе рассмотреть период начиная с 2005 года и опираясь на рейтинг продаж 16го года, ибо мертвые платформы нас точно не интересуют.

# %%
df = df[df["year_of_release"] >= 2005]
platform_total_sales = (df[df["year_of_release"] >= 2016].
                  pivot_table(index="platform", 
                              values="total_sales", 
                              aggfunc="sum")
                  .sort_values(by="total_sales", ascending=False)
                 )
platform_sales = df.pivot_table(index="platform",columns="year_of_release", values="total_sales", aggfunc="sum")
platform_pivot = platform_total_sales.join(platform_sales).drop("total_sales", axis=1)
plt.figure(figsize=(20, 10))
sns.heatmap(platform_pivot, annot=True, fmt=".3g", cmap="Blues", linewidths=1, linecolor="gray")
# Out:
# <AxesSubplot:ylabel='platform'>

# %% [markdown]
# Исходя из наблюдаемой картины, я считаю актуальным для прогноза прибыльности платформ период, в который существовали все платформы шестерки лидеров продаж на 16год, а именно от 13го года. Думаю, этого будет достаточно, чтобы проследить динамику.
# Так же мы видим, что все существующие на данный момент платформы находятся на спаде не смотря на молодость некоторых из них, не считя PC. там продажи никогда не были слишком высокими, но присутствует явная стабильность на протяжении более 20 лет и со взлетом в 10-12 годах.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Правильный выбор диапазона!
#
# Это на самом деле один из подводных камней этого проекта!
#
# Студенты могут выбирать для анализа очень большой интервал данных, но для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-4 года. И в такой динамично меняющейся индустрии, как компьютерные игры также не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. В нашем учебном проекте, я с тобой соглашусь, что 4 года: 2013 - 2015 + неполный 2016 - ОК.</div>

# %%
# сокращаем таблицу до актуального периода
df = df[df["year_of_release"] >= 2013]
# список топ платформ
top6_platform = ["PS4", "XOne", "3DS", "PC", "WiiU","PSV"]
# выборка для ящиков с усами
top_6 = df.query('platform in @top6_platform')
top_6["platform"].unique()
# Out:
# array(['PS4', '3DS', 'XOne', 'WiiU', 'PC', 'PSV'], dtype=object)

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Единственный момент, на будущее - когда делаешь срез из оригинального датафрейма старайся сохранять его под новым именем. Этим ты будешь гарантировать, что в **df** у тебя всегда находятся полные, ОРИГИНАЛЬНЫЕ, очищенные и предобработанные данные.
#
# **ПРИМЕР**: например, обрезая данные 2015 годом я бы сохранил их в новый датафрейм так (**псевдокод!**): **data_2015 = data[data['year_of_release']>=2014]**
#
# Далее/же продолжил бы работать с **data_2015** ... А теперь допустим ещё ниже мне понадобилось бы сделать другой срез, из полного оригинального датафрейма. И тогда я бы тогда написал что-нибудь типа: **data_before2000 = data[data['year_of_release'] <= 2000]**. И это бы сработало.
#
# А в твоём случае - нет, потому что в **df** у тебя теперь находится не полные оригинальные данные, а срез «выше» 2013 года. Мне удалось донести мысль? В общем порядок такой: загрузили данные из csv, обработали пропуски, почистили, сделали все необходимое и ОСТАВИЛИ для любых дальнейших обращений к нему. А для решения промежуточных локальных задач делай срезы из полного датафрейма, но сохраняй эти срезы под собственными именами (не перезатирай оригинальные данные).</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Понял. учту. мысль вполне ясна. в других работах я так и делал, но здесь в плане работы особо подчеркнуто, что после выбора актуального периода, все остальные исследования нужно проводить только для этого среза, этим и руководствовался. Сейчас не хочется лопатить всю дальнейшую работу и заниматься дописываниями в каждой строке. надеюсь, это не критично.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Нет Павел, не критично. Это на будущее. Прсто оставляй за спиной цепочку данных, чтобы всегда можно было вернуться к чуть более старым данным.</div>

# %%
plt.figure(figsize=(20, 12))
sns.boxplot(data=top_6, x="platform", y="total_sales")
plt.ylim(0, 3)
plt.grid()
plt.show()
top_6.groupby("platform")["total_sales"].describe()
# Out:
#           count      mean       std   min   25%   50%    75%    max
# platform
# 3DS       303.0  0.472772  1.381347  0.01  0.04  0.09  0.280  14.60
# PC        189.0  0.208624  0.352304  0.01  0.03  0.08  0.230   3.05
# PS4       392.0  0.801378  1.609456  0.01  0.06  0.20  0.730  14.63
# PSV       358.0  0.092151  0.153816  0.01  0.02  0.04  0.110   1.96
# WiiU      115.0  0.562000  1.038778  0.01  0.06  0.20  0.595   7.09
# XOne      247.0  0.645020  1.036139  0.01  0.06  0.22  0.685   7.39

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# К сожалению, на этом графике **уверенно** сравнивать квартили (медиану, 25ый и 75ый) у части платформ не получается. Велика вероятность ошибки. Для более обоснованных выводов на основе **только графика** (иначе зачем такой **неговорящий график нужен**) нужно сделать дополнительный график, где будет отображена только нижняя часть boxplot-ов. Этого можно добиться, например, задав параметр ylim
#
# То есть, я бы предложил после этого графика ещё один построить, в котором бы сами "ящики" были лучше видны. На том, что выше выбросы их фактически "забили". Попробуй использовать в параметре ylim, значение, которое ещё больше ограничит значение по OY "сверху" (например, ylim(0, 0.85). Ну и «строй» график большего размера (попробуй использовать: plt.figure(figsize=[20, 10]).
#
# Ну а в твоем случае, из-за того, что на графике не разобрать квартили - для точного сравнения "ящиков" мы вынуждены будем использовать describe().</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>согласен, что график "не говорящий". пожалуй, это действительно не лучший вариант, потому и вывел табличку с дискрайбами, чтобы четче были видны значения, я задал ограничение по игрику исходя из важности визуализации выбросов, но ящики действительно получились так себе
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Ну да, получается либо "говорящий" график, либо **дескрайб**. Но лучше и то и другое!</div>

# %%
plt.figure(figsize=(20, 12))
sns.boxplot(data=top_6, x="platform", y="total_sales")
plt.ylim(0, 0.85)
plt.grid()
plt.show()

# %% [markdown]
# если на хитмэпе PSV и Wiiu выглядели одинаково неприглядно, и не внушали доверия, то сейчас картина сильно изменилась. у нас определилась пятерка лидеров.
# В первую очередь мы видим огромное кличество выбросов, что в очередной раз подтверждает, что на суммарные продажи сильное влияние оказывает популярность определенных игр. наименее значительные выбросы у PSV при этом количество выпущенных на этой платформе игр на втором месте, а среднее продаж на последнем. у Wiiu достаточно высокое среднее, медиана наравне с лидерами, и не так много выбросов, значит выпускаемые на этой платформе игры достаточно стабильно пользуются популярностью.
# По PS4 и XOne картинки похожи, не считая того, что на PS4 выпустили значительно больше игр и очень большой разброс: третий квартиль значительно выше, при этом медиана немного выше у ХОne. У PC немного выбросов, совсем невысокий максимум. в общем всё достаточно четко и стабильно.

# %% [markdown]
# Посмотритм на примере PS4, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.

# %%
# корреляция рейтинг-продажи
ps = top_6[top_6["platform"] == "PS4"]
print("Коэффицент корреляции между рейтингом критиков и продажами:")
display(ps["critic_score"].corr(ps["total_sales"]))
print("Коэффицент корреляции между рейтингом пользователей и продажами:")
display(ps["user_score"].corr(ps["total_sales"]))
ps.plot(x="critic_score", y="total_sales", kind="scatter", alpha=0.5, grid=True)
ps.plot(x="user_score", y="total_sales", kind="scatter", alpha=0.5, grid=True)
plt.show()
# Out:
# Коэффицент корреляции между рейтингом критиков и продажами:
# 0.4065679020617816
# Коэффицент корреляции между рейтингом пользователей и продажами:
# -0.031957110204556424

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Тут всё верно, мы выбрали одну из платформ и проверили линейную зависимость между продажами и оценками пользователей и экспертов.
#
# И вот здесь именно то место, которое упрощает жизнь за счет того, что мы не заполняли пропуски в 'critic_score' и 'user_score'. Если бы это было иначе - перед анализом корреляций надо было бы эти заполненные значения не учитывать (отфильтровывать).
#
# Ввиду же того, что "пропуски" в столбцах с соответствующими оценками мы "заглушками" заполнять не стали (а NaN – значения метод .corr() не учитывает (ссылка на документацию: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html?highlight=corr#pandas.DataFrame.corr)), то и перед передачей данных в метод .corr() отфильтровывать нам их не пришлось.</div>

# %% [markdown]
# Мы видим, что связи между оценками пользователей и продажами не наблюдается, однако, явно видна связь между рейтингом критиков и продажами, хотя и слабая, и не скажешь, что тут является причиной, а что следствием. При высоких рейтингах критиков, основное количество игр все равно имеет низкие продажи, как и при низких оценках, но среди высоко оцененных как раз все эти выбросы с высокими продажами, сочетания высоких продаж с низкими рейтингами нет. Посмотрим на корреляции для других платформ

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Дьявол кроется в формулировках: ** явно видна связь между рейтингом критиков и продажами** - говорить так в общем случае неверно.
#
# ---
#
# Формулировать, что коэффициент  корреляции (Пирсона) между 2 переменными (в нашем случае между "total_sales" и "critic_score") есть показатель того, что **на количество продаж влияет оценка ** - неверно. Корреляция не подразумевает наличие причинно-следственной связи между переменными.
#
# Коэффициент свидетельствует **о наличии или отсутствии линейной связи** между переменными, и **измеряет выраженность** этой связи. Другими словами, коэффициент корреляции - это инструмент, с помощью которого можно проверить гипотезу о **линейной** зависимости и измерить степень этой зависимости.
#
# Например, в нашем случае, связь между продажами и оценками экспертов для всех платформ является **прямой, слабой** степени выраженности (во всех случаях коэффициент около 0,3-0,4).
#
# Я бы твою фразу переписал бы так (**ПРИМЕР**): "Оценки критиков демонстрируют прямую, средне-слабую корреляцию с "цифрами" продаж. Оценки пользователей корреляции с продажами не имеют".
#
# Понимаешь, нет влияния оценок на продажи. Коэффициент корреляции Пирсона не про это. Он про линейную зависимость 2-х переменных. И ещё, это коэффициент **НЕ ОБЪЯСНЯЕТ** зависимость, он **НЕ ГОВОРИТ** почему наблюдается такой эффект, но просто констатирует факт, что корреляция наблюдается (например, "мы видим, что те игры, которым наши эксперты дают высокие оценки - продаются лучше". А вот почему они продаются лучше - можно только предполагать ... разные причины могут быть). Вот смешная статейка на эту тему: https://ktonanovenkogo.ru/voprosy-i-otvety/korrelyaciya-chto-ehto-takoe-prostymi-slovami.html</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>дал маху с объяснениями корреляции Пирсона))) Тут для меня многое прояснилось! Спасибо!
#     </font>
# </div>

# %% [markdown]
# Между оценками критиков и продажами присутствует слабая прямая корреляция. Корреляции между оценками пользователей и продажами не наблюдается.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>так?)
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да!</div>

# %%
# делаем табличку с корреляциями
cor = pd.DataFrame(data = top_6["platform"].unique(), columns=["platform"])
user_corr = []
critic_corr = []
for x in cor["platform"]:
    y = df[df["platform"] == x]
    critic = y["critic_score"].corr(y["total_sales"])
    critic_corr.append(critic)
    user = y["user_score"].corr(y["total_sales"])
    user_corr.append(user)

cor["user_corr"] = user_corr
cor["critic_corr"] = critic_corr
cor
# Out:
#   platform  user_corr  critic_corr
# 0      PS4  -0.031957     0.406568
# 1      3DS   0.241504     0.357057
# 2     XOne  -0.068925     0.416998
# 3     WiiU   0.419330     0.376415
# 4       PC  -0.093842     0.196030
# 5      PSV   0.000942     0.254742

# %% [markdown]
# стоит отметить, что для WiiU связь между оценками пользователей и продажами значительо выше, чем для остальных платформ, а так же, что на продажи PC никакие рейтинги не оказывают практически никакого влияния

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# **на продажи PC никакие рейтинги не оказывают практически никакого влияния** - ПАвел, так говорить неверно.
# </div>

# %% [markdown]
# стоит отметить, что для платформы WiiU в отличае от остальных платформ присутствует слабая прямая корреляция между оценками пользователей и продажами, а так же, что продажи на PC не коррелируют ни с рейтингом критиков ни с рейтингом пользователей

# %% [markdown]
# Посмотрим на общее распределение игр по жанрам.

# %%
# делает табличку и сортируем по суммарным продажам
genre = df.groupby("genre").agg(
    {
        "name": "count",
        "total_sales": ["sum", "mean", "median", "max"]
    }
)
genre.columns = ["num_of_games", "total_sales", "mean_sales", "median_sales", "max_sales"]
genre = genre.sort_values("total_sales", ascending=False)
display(genre)

plt.figure(figsize=(12, 8))
plt.grid()
plt.bar(genre.index, genre["num_of_games"], alpha=0.7, label="number of games")
plt.bar(genre.index, genre["total_sales"], alpha=0.7, label="total sales")
plt.legend()
plt.show()
# если раскоментить, то можно посмотреть наглядную разницу между максимальными продажами и средними и медианными значениями
# plt.figure(figsize=(12, 12))
# plt.grid()
# plt.bar(genre.index, genre["max_sales"], alpha=0.7)
# plt.bar(genre.index, genre["mean_sales"], alpha=0.7)
# plt.bar(genre.index, genre["median_sales"], alpha=0.7)
# plt.show()
# Out:
#               num_of_games  total_sales  mean_sales  median_sales  max_sales
# genre
# Action                 766       321.87    0.420196         0.110      21.05
# Shooter                187       232.98    1.245882         0.450      14.63
# Sports                 214       150.65    0.703972         0.240       8.58
# Role-Playing           292       145.89    0.499623         0.125      14.60
# Misc                   155        62.82    0.405290         0.100       9.18
# Platform                74        42.63    0.576081         0.225       4.32
# Racing                  85        39.89    0.469294         0.120       7.09
# Fighting                80        35.31    0.441375         0.125       7.55
# Adventure              245        23.64    0.096490         0.030       1.66
# Simulation              62        21.76    0.350968         0.100       5.22
# Strategy                56        10.08    0.180000         0.080       1.67
# ...

# %% [markdown]
# Здесь мы видим грустные показатели жанра Adventure,игр в котором было выпущено неоправданно много, а так же Simulation, Strategy, Puzzle, которых выпускают так же мало, как и продают. Еще бросаются в глаза показатели жанра Shooter: вторые продажи при значительно меньшем объеме выпущенных игр относительно лидера. Action - лидирует по продажам, однако и игр в этом жанре выпущено в разы больше, чем в других. второй и четвертый по количеству выпускаемых игр жанры Role-Playing и Sports соответственно, по продажам они так же занимают лидирующие места

# %% [markdown]
# <div class="alert alert-success">
# <b>ОК 👍</b>
#
# Это одно из сложных мест в этом проекте: зачастую студенты делают вывод о выгодности жанра по количеству проданных копий (по этому параметру должны бы выиграть Action-игры), а не по среднему/медианному значению.
# Отлично что ты понимаешь, что общие продажи - это не очень корректная метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние (или медианные продажи или продажи, приведенные на одну игру), что собственно ты и делаешь!</div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# В результате исследовательского анализа данных
# 1. Был определен актуальный период для определения факторов прибыльности той или иной игры.
# 2. Определены средние жизненные циклы популярных платформ и "живые" на актуальный период платформы.
# 3. Была выявлена слабая прямая корреляция между рейтингами критиков и продажами игры, так же выявленно отсутствие такой взаимосвязи между пользовательскими рейтингами и продажами для большинства платформ.

# %% [markdown]
# ## Портрет пользователя каждого региона

# %%
# табличка распределения продаж платформ по регионам
region_platform = df.groupby("platform")[["na_sales", "eu_sales", "jp_sales"]].sum()
region_platform
# Out:
#           na_sales  eu_sales  jp_sales
# platform
# 3DS          38.20     30.96     67.81
# DS            0.57      0.85      0.00
# PC           11.11     25.36      0.00
# PS3          63.50     67.81     23.35
# PS4         108.74    141.09     15.96
# PSP           0.00      0.17      3.29
# PSV           5.04      6.10     18.59
# Wii           6.56      5.93      0.05
# WiiU         29.21     19.85     10.88
# X360         81.66     42.52      0.51
# XOne         93.12     51.59      0.34

# %%
# визуализация
# северная америка
na_p = region_platform["na_sales"].sort_values(ascending=False)
plt.figure(figsize=(6, 4))
plt.title("Доли продаж Топ-5 платформ в Северной Америке")
plt.grid()
plt.ylim(0, 120)
plt.bar(na_p.head().index, na_p.head())
for i in range(len(na_p.head())):
    plt.text(na_p.index[i], na_p[i]+3, f"{na_p[i] / na_p.sum():.1%}", ha="center")
# европа
eu_p = region_platform["eu_sales"].sort_values(ascending=False)
plt.figure(figsize=(6, 4))
plt.title("Доли продаж Топ-5 платформ в Европе")
plt.grid()
plt.ylim(0, 155)
plt.bar(eu_p.head().index, eu_p.head())
for i in range(len(eu_p.head())):
    plt.text(eu_p.index[i], eu_p[i]+3, f"{eu_p[i] / eu_p.sum():.1%}", ha="center")
# япония
jp_p = region_platform["jp_sales"].sort_values(ascending=False)
plt.figure(figsize=(6, 4))
plt.title("Доли продаж Топ-5 платформ в Японии")
plt.grid()
plt.ylim(0, 75)
plt.bar(jp_p.head().index, jp_p.head())
for i in range(len(jp_p.head())):
    plt.text(jp_p.index[i], jp_p[i]+2, f"{jp_p[i] / jp_p.sum():.1%}", ha="center")
    
plt.show()

# %%
# смотрим продажи по регионам
u = df["na_sales"].sum()
print(f"Суцммарные продажи за актуальный период в Северной Америке: {u:.1f} млн копий")
e = df["eu_sales"].sum()
print(f"Суцммарные продажи за актуальный период в Европе: {e:.1f} млн копий")
j = df["jp_sales"].sum()
print(f"Суцммарные продажи за актуальный период в Японии: {j:.1f} млн копий")
# Out:
# Суцммарные продажи за актуальный период в Северной Америке: 437.7 млн копий
# Суцммарные продажи за актуальный период в Европе: 392.2 млн копий
# Суцммарные продажи за актуальный период в Японии: 140.8 млн копий

# %% [markdown]
# Японские продажи в целом в 3 раза ниже, чем европейские и северо-американские присутствуют координальные отличия в популярности платформ. Топ-5 платформ в Европе и Северной Америке идентичны, не считая того, что доля продаж PS4 в европе составляет практически половину всех продаж и места распределились немного иначе. в европе более популярна платформа PS3, нежели прочие лидеры. В Сев. Америке продажи распределены более равномерно. При этом в Японии доля продаж игр на PS4 составляет всего 11% и половина продаж приходится на 3DS, который находится на последнем месте в топ-5 по другим регионам. так же в японский рейтинг попали PSV и WiiU

# %%
# табличка распределения продаж жанров по регионам
region_genre = df.groupby("genre")[["na_sales", "eu_sales", "jp_sales"]].sum()
region_genre
# Out:
#               na_sales  eu_sales  jp_sales
# genre
# Action          126.05    118.13     40.49
# Adventure         7.14      8.25      5.82
# Fighting         15.55      8.55      7.65
# Misc             27.49     20.04      9.20
# Platform         18.14     15.58      4.79
# Puzzle            0.83      1.00      1.18
# Racing           12.96     20.19      2.30
# Role-Playing     46.40     36.97     51.04
# Shooter         109.74     87.86      6.61
# Simulation        4.86     10.92      4.52
# Sports           65.27     60.52      5.41
# Strategy          3.28      4.22      1.77

# %%
# визуализация
# америка
na_g = region_genre["na_sales"].sort_values(ascending=False).head()
plt.figure(figsize=(6, 4))
plt.title("Доли продаж Топ-5 жанров в Северной Америке")
plt.grid()
plt.ylim(0, 140)
plt.bar(na_g.head().index, na_g.head())
for i in range(len(na_g.head())):
    plt.text(na_g.index[i], na_g[i]+3, f"{na_g[i] / na_g.sum():.1%}", ha="center")
    
# европа
eu_g = region_genre["eu_sales"].sort_values(ascending=False)
plt.figure(figsize=(6, 4))
plt.title("Доли продаж Топ-5 жанров в Европе")
plt.grid()
plt.ylim(0, 130)
plt.bar(eu_g.head().index, eu_g.head())
for i in range(len(eu_g.head())):
    plt.text(eu_g.index[i], eu_g[i]+2, f"{eu_g[i] / eu_g.sum():.1%}", ha="center")
    
# япония
jp_g = region_genre["jp_sales"].sort_values(ascending=False)
plt.figure(figsize=(6, 4))
plt.title("Доли продаж Топ-5 жанров в Японии")
plt.grid()
plt.ylim(0, 60)
plt.bar(jp_g.head().index, jp_g.head())
for i in range(len(jp_g.head())):
    plt.text(jp_g.index[i], jp_g[i]+1, f"{jp_g[i] / jp_g.sum():.1%}", ha="center")
    
plt.show()

# %% [markdown]
# И снова мы наблюдаем поразительное сходство во вкусах Северной Америки и Европы. Здесь их показатели практически идентичны, однако в Северной Америке жанр Action лидирует не с таким большим отрывом, как в Европе.
# Так же Action популярен и в Японии, но находится на второ месте после Role-Playing - вместе эти 2 жанра занимают более 60% всех продаж. В Европе и Америке Role-Playing не пользуется такой популярностью

# %% [markdown]
# Проверим взаимосвязь возрастных рейтингов с продажами по регионам

# %%
rating = df.groupby("rating")[["na_sales", "eu_sales", "jp_sales"]].sum()
rating
sns.heatmap(rating, annot=True, fmt=".3g", cmap="Blues", linewidths=1, linecolor="gray")
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Один из подводных камней этого проекта. Суть его в том, что часто студенты в самом начале «тетрадки» пропуски в 'rating' не обрабатывают, оставляют NaN, и соответственно во время анализ и/или построении графиков игры без рейтингов «теряются».</div>

# %% [markdown]
# В Северной Америке наибольшей популярностью явно пользуется рейтинг 17+, вторую долю по величине занимает раздел игр с неизвестным рейтингом, так что полагаться на достоверность данных не стоит, далее идет рейтинг Е(для всех). В европе картина пропорционально идентична. В Японии с большим отрывом лидирует неизвестный жанр, об остальном здесь судить явно не стоит

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# А чем на твой взгляд можно объяснить то, что в Японии лидерами продаж (в количестве копий) являются игры без рейтинга ESRB?</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Ну вот, видимо, как раз с тем, что в японии популярны платформы не популярные в США, и большинство игр на них просто не выходит в америке и не получает рейтингов.
#     </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, про это чуть выше был комментарий.</div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Сравнение популярных платформ и жанров показало, что пользователи из Северной Америки и Европы очень близки в предпочтениях между собой, а предпочтения японских пользователей отличаются координально и в целом японские продажи значительно ниже.
# платформа 3DS имеет в японии очень большую популярность при незначительной популярности в остальных регионах, как и жанр Role-playing.
# Связь между возрастным рейтингом и продажами в силу недостаточности достоверных данных о рейтингах. Но для европы и С.Америки был определен самый популярный рейтинг 17+

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Гпотеза №1

# %% [markdown]
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковы

# %% [markdown]
# Предполагается, что данные за рассматриваемый период могут быть неполными, соответственно дисперсию будем считать для выборки

# %%
# группируем
xone_user_score = df[(df["platform"] == "XOne") & (df["user_score"].notna())]["user_score"]
pc_user_score = df[(df["platform"] == "PC") & (df["user_score"].notna())]["user_score"]

# характеристики
print("Дисперсия:")
display(xone_user_score.var())
display(pc_user_score.var())

print("Длина срезов:")
display(len(xone_user_score))
display(len(pc_user_score))

print("Средние:")
display(xone_user_score.mean())
display(pc_user_score.mean())
# Out:
# Дисперсия:
# 1.9069968429360695
# 3.035892752408882
# Длина срезов:
# 182
# 155
# Средние:
# 6.521428571428572
# 6.2696774193548395

# %% [markdown]
# Применим метод для проверки гипотезы о равенстве среднего двух генеральных совокупностей по взятым из них выборкам. учитывая, что размеры выборок и дисперсия сильно отличаются, укажем параметр equal_var
#
# Примем за нулевую гипотезу:
#
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковы.
#
# Альтернативная гипотеза:
#
# Средние пользовательские рейтинги платформ Xbox One и PC отличаются

# %%
alpha = .05
result = st.ttest_ind(xone_user_score, pc_user_score, equal_var=False)
if result.pvalue < alpha:
    print(result.pvalue, " Отвергаем")
else:
    print(result.pvalue, " Не отвергаем")
# Out:
# 0.14759594013430463  Не отвергаем

# %% [markdown]
# P-величина почти в 3 раза больше достаточно высокого значения уровня критической значимости. Не отвергаем нулевую гипотезу.
#
# На основе статистического теста гипотиза о сходстве средних пользовательских рейтингов платформ Xbox One и PC не может быть отвергнута

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что ты не забываешь отфильтровать «заглушки» / NaN значения.
#
# Также верно и то, что мы используем здесь двусторонний тест.
#
# Ну и отлично, что ты понимаешь, что нельзя сделать вывод, что тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии). Например так: «У нас нет оснований утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются».</div>

# %% [markdown]
# ### Гипотеза №2

# %% [markdown]
# Средние пользовательские рейтинги жанров Action и Sports не одинаковы.

# %%
# группируем
action_user_score = df[(df["genre"] == "Action") & (df["user_score"].notna())][["user_score"]]
sports_user_score = df[(df["genre"] == "Sports") & (df["user_score"].notna())][["user_score"]]

# характеристики
print("Дисперсия:")
display(action_user_score.var())
display(sports_user_score.var())

print("Длина срезов:")
display(len(action_user_score))
display(len(sports_user_score))

print("Средние:")
display(action_user_score.mean())
display(sports_user_score.mean())
# Out:
# Дисперсия:
# user_score    1.769361
# dtype: float64
# user_score    3.180613
# dtype: float64
# Длина срезов:
# 389
# 160
# Средние:
# user_score    6.837532
# dtype: float64
# user_score    5.238125
# dtype: float64

# %% [markdown]
# Здесь мы так же видим большое различие в размере списков и значении дисперсии, значит дисперсию в статистическом тесте нужно считать отдельно
#
# Нулевая гипотеза:
#
# Средние пользовательские рейтинги жанров Action и Sports одинаковы.
#
# Альтернативная гипотеза:
#
# Средние пользовательские рейтинги жанров Action и Sports отличаются

# %%
alpha = .05
result = st.ttest_ind(action_user_score, sports_user_score, equal_var=False)
if result.pvalue < alpha:
    print(result.pvalue, " Отвергаем")
else:
    print(result.pvalue, " Не отвергаем")
# Out:
# [1.44600397e-20]  Отвергаем

# %% [markdown]
# P-величина крайне мала. Отвергаем нулевую гипотезу
#
# На основе статистического теста мы отвергли нулевую гипотезу в пользу альтернативной.

# %% [markdown]
# ### Вывод

# %% [markdown]
# По результатам проверки гипотез мы видим, что не имеем оснований отвергать гипотезу о равенстве средних пользовательских рейтингов платформ Xbox One и PC, но имеем основания отвергнуть гипотезу о равенстве рейтингов жанров Action и Sports.

# %% [markdown]
# ## ВЫВОД

# %% [markdown]
# По результатам исследования многое прояснилось:
# 1. Предпочтения японских пользователей сильно отличаются от европейских и северо-американских и продажи в Японии в целом значительно ниже, соответственно, если и ориентироваться на Японию, то стоит обратить внимание на платформу 3DS (Эта платформа популярна только там) и жанр Role-playing.
# 2. В Европе и Японии все еще популярна PS3, но судя по динамике ее продаж и, зная средний размер жизненного цикла платформ, можно предположить, что 16ый год был последним годом ее жизни, я не стал бы рассчитывать на нее в 17ом
# 3. PC не попала в рейтинги самых популярных платформ по регионам, но стабильна, при небольшой прибыльности на протяжении более 20лет
# 4. На данный момент все представленные в датасете платформы идут на спад, причем достаточно повально. среди относительно молодых платформ все еще пользуются популярностью PS4, XOne, 3DS. учитывая общие тенденции, можно предположить, что вскоре должны появиться новые платформы.
# 5. Если не брать в рассчет Японию, наиболее популярными жанрами можно считать Action и Shooter(в Японии Action тоже популярен)
# 6. Самые популярные в Европе и Северной америке платформы, не считая умирающей PS3, PS4 и XOne.(Япония за 3DS)

# %% [markdown]
# # Результат ревью:
#
# Павел, я отмечаю высокий уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python и библиотеки pandas. Всё это в целом упрощает твой код и одновременно показывает твой уровень владения инструментами.
#
# Ты умело применяешь графические библиотеки (seaborn), выбираешь для визуализации ровно те типы графиков, которые нужны. Если ещё поработать над тем, чтобы все оси были подписаны и графики имели понятные названия, то будет просто отлично.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Однако есть принципиальные моменты, которые не позволяют мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# 1. Нужен твой комментарий, касающийся природы пропусков в столбце с рейтингами, а именно, может ли быть какая-то связь с тем, что в столбце с рейтингами >40% пропусков и тем, что эти оценки (рейтинги) выставляет **именно Американское рейтинговое агентство?
#
# 2. В разделе построения «ящика с усами» по глобальным продажам игр в разбивке по платформам необходимо построить график так, чтобы квартили соответствующих «ящиков» позволяли визуально сравнивать платформы между собой. **Все боксплоты** нужно построить на одном графике.
#
# 3. Формулировать, что коэффициент (линейной) корреляции (Пирсона) между 2 переменными (в нашем случае между "продажами" и "оценками") есть показатель **влияния оценок на количество продаж** - неверно.</div>
#
# Эти 3 момента требуют твоего внимания. Комментарии по ним помечены красным цветом.
#
# Подводя итог: отличная работа на самом-то деле, молодец! Есть несколько моментов к исправлению, но уверен, что они не вызовут у тебя сложностей. После доработки обязательно проверь комментарии и выводы. Возможно их нужно будет скорректировать. Жду доработанную версию проекта на повторное ревью.
